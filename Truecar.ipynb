# %%
import pandas as pd
import numpy as np

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HP

# %%
file_path =r"C:\Users\HP\Downloads\True Car Data\true_car_listings.csv"
df= pd.read_csv(file_path)
df
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# ...

# %%
df.head(10)

# %%
df.tail(10)
df
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# ...

# %%
# DROP ID

# %%
df = df.drop("Id", axis=1)
df

# %%
# DROP DUPLICATES

# %%
df = df.drop_duplicates()
df
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model  Car Age
# 0       Acura    ILX6-Speed       10
# ...

# %%
# IDENTIFY MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
#COLUMN TYPE

# %%
print(df.dtypes)
# Out:
# Price       int64
# Year        int64
# Mileage     int64
# City       object
# State      object
# Vin        object
# Make       object
# Model      object
# dtype: object

# %%
#DESCRIPTIVE ANALYSIS

# %%
df.describe()
# Out:
#                Price           Year       Mileage
# count  852122.000000  852122.000000  8.521220e+05
# mean    21464.100210    2013.289145  5.250779e+04
# std     13596.202241       3.414987  4.198896e+04
# min      1500.000000    1997.000000  5.000000e+00
# 25%     13000.000000    2012.000000  2.383600e+04
# 50%     18500.000000    2014.000000  4.025600e+04
# 75%     26995.000000    2016.000000  7.218600e+04
# max    499500.000000    2018.000000  2.856196e+06

# %%
df.describe(include='object')
# Out:
#            City   State                Vin    Make      Model
# count    852122  852122             852122  852122     852122
# unique     2553      59             852075      58       2736
# top     Houston      TX  2G1FA1E37E9293949    Ford  Silverado
# freq      12703   94654                  2  110432      24932

# %% [raw]
# #REMOVE DUPLICATE FROM VIN

# %%
df = df.drop_duplicates(subset='Vin')
df
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# ...

# %%
z_scores = (df[['Price', 'Year', 'Mileage']] - df[['Price', 'Year', 'Mileage']].mean()) / df[['Price', 'Year', 'Mileage']].std()
z_scores
# Out:
#            Price      Year   Mileage
# 0      -0.917102  0.208157 -0.399695
# 1      -0.777872 -0.084669 -0.783582
# 2      -0.917102 -0.084669 -0.087089
# 3      -0.769708  0.208157 -0.299741
# 4      -0.490218  0.793811 -0.723185
# ...          ...       ...       ...
# 852117  3.070777  1.086638 -1.250300
# 852118  3.736036  1.086638 -1.174280
# 852119  2.540040  0.793811 -0.561262
# 852120  2.851966  1.086638 -1.178948
# 852121  4.084295  1.086638 -1.190927
#
# [852122 rows x 3 columns]

# %%
outliers = df[z_scores.abs() > 3]
outliers
# Out:
#           Price  Year  Mileage City State  Vin Make Model
# 0           NaN   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# 1           NaN   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# 2           NaN   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# 3           NaN   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# 4           NaN   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# ...         ...   ...      ...  ...   ...  ...  ...   ...
# 852117  63215.0   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# 852118  72260.0   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# 852119      NaN   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# 852120      NaN   NaN      NaN  NaN   NaN  NaN  NaN   NaN
# 852121  76995.0   NaN      NaN  NaN   NaN  NaN  NaN   NaN
#
# [852122 rows x 8 columns]

# %%
import datetime

# %%
df['Car Age'] = datetime.datetime.now().year - df['Year']
df
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model  Car Age
# 0       Acura    ILX6-Speed       10
# ...

# %%
skewness = df['Price'].skew()
print("Skewness coefficient:", skewness)
# Out:
# Skewness coefficient: 5.291308439037201

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Price'])
# Out:
# (array([8.31733e+05, 1.85990e+04, 1.02400e+03, 3.77000e+02, 1.74000e+02,
#         7.70000e+01, 3.90000e+01, 2.80000e+01, 1.60000e+01, 8.00000e+00]),
#  array([  1500.,  51300., 101100., 150900., 200700., 250500., 300300.,
#         350100., 399900., 449700., 499500.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Mileage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20b1efdb650>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20b23341f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20b233417c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20b233423f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20b233426c0>],
#  'means': []}

# %%
plt.scatter(df['Mileage'], df['Price'])
